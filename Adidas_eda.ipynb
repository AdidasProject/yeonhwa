# %% [markdown]
# ##시각화

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## product

# %% [markdown]
# ### product별 total_sales

# %%
product01 = pd.read_csv('/content/drive/MyDrive/project01_adidas/product_result01.csv')
product01
# Out:
#                      product  total_sales  count
# 0      Men's Street Footwear    208826244   1610
# 1            Women's Apparel    179038860   1608
# 2    Men's Athletic Footwear    153673680   1610
# 3    Women's Street Footwear    128002813   1608
# 4              Men's Apparel    123728632   1606
# 5  Women's Athletic Footwear    106631896   1606

# %%
product01 = product01.sort_values('product',ascending=False)
plt.title("Total Saeles by Product")
sns.barplot(x="product", y="total_sales", data=product01)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# 1. product별 total_sales
# - 카테고리 6개.
# - Men's Street Footwear이 제일 판매량 높음.
# - 모든 카테고리에서 남성제품의 판매량이 더 높음.
# - apparel보다는 footwear의 판매량이 더 높음.
# - 신발 카테고리만 더 세분화 되어 있음. —> 옷보다는 신발이 많이 팔린다는 것을 알 수 있음.

# %% [markdown]
# ### 년도별, product별 total sales

# %%
# 2020
product02 = pd.read_csv('/content/drive/MyDrive/project01_adidas/product_result02.csv')
product02
# Out:
#                      product  total_sales
# 0      Men's Street Footwear     37823020
# 1            Women's Apparel     35190332
# 2    Men's Athletic Footwear     31794462
# 3    Women's Street Footwear     27426005
# 4              Men's Apparel     26216964
# 5  Women's Athletic Footwear     23629892

# %%
product02 = product02.sort_values('product',ascending=False)
plt.title("2020 Total Saeles by Product")
sns.barplot(x="product", y="total_sales", data=product02)
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2021
product03 = pd.read_csv('/content/drive/MyDrive/project01_adidas/product_result03.csv')
product03
# Out:
#                      product  total_sales
# 0      Men's Street Footwear    171003224
# 1            Women's Apparel    143848528
# 2    Men's Athletic Footwear    121879218
# 3    Women's Street Footwear    100576808
# 4              Men's Apparel     97511668
# 5  Women's Athletic Footwear     83002004

# %%
product03 = product03.sort_values('product',ascending=False)
plt.title("2021 Total Saeles by Product")
sns.barplot(x="product", y="total_sales", data=product03)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# 2. 년도에 따른 상품의 매출 경향의 변화
# - 2020 → 2021년이 되면서 product별 매출에 변화가 있는지 살펴본 결과, product의 매출 순서에는 변함이 없음.
# - 전체적으로 모든 카테고리에서 매출이 늘었다는 것을 알 수 있음.

# %% [markdown]
# ### Products별 Units sold

# %%
product04 = pd.read_csv('/content/drive/MyDrive/project01_adidas/product_result04.csv')
product04
# Out:
#                      product  units_sold
# 0      Men's Street Footwear      593320
# 1    Men's Athletic Footwear      435526
# 2            Women's Apparel      433827
# 3    Women's Street Footwear      392269
# 4  Women's Athletic Footwear      317236
# 5              Men's Apparel      306683

# %%
product04 = product04.sort_values('product',ascending=False)
plt.title("Units sold by Product")
sns.barplot(x="product", y="units_sold", data=product04)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# 3. Products별 Units sold
# - 매출이 가장 높은 Men’s Street Footwear가 units sold도 가장 많음을 알 수 있음.

# %% [markdown]
# ### 월별 product별 판매 경향

# %%
gender06 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender06.csv')
gender06
# Out:
#                       Product  year  month  total_sales
# 0       Men's Street Footwear  2020      1      3859495
# 1             Women's Apparel  2020      1      3066713
# 2     Men's Athletic Footwear  2020      1      2639958
# 3     Women's Street Footwear  2020      1      2409037
# 4               Men's Apparel  2020      1      2288362
# ..                        ...   ...    ...          ...
# 67            Women's Apparel  2020     12      1690464
# 68  Women's Athletic Footwear  2020     12      1188955
# 69    Men's Athletic Footwear  2020     12      1065239
# 70              Men's Apparel  2020     12      1018079
# 71    Women's Street Footwear  2020     12       952369
#
# [72 rows x 4 columns]

# %%
gender06 = gender06.sort_values('Product',ascending=False)
sns.lineplot(data=gender06,x=gender06['month'],y='total_sales',hue="Product")
plt.title("Sales trend by Product (2020)")
plt.xticks(np.arange(1,13))
#plt.ylim(0,30000000)
plt.show()

# %%
gender07 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender07.csv')
gender07
# Out:
#                       Product  year  month  total_sales
# 0       Men's Street Footwear  2021      1     11734700
# 1     Men's Athletic Footwear  2021      1     10451678
# 2             Women's Apparel  2021      1     10286615
# 3     Women's Street Footwear  2021      1      8430191
# 4               Men's Apparel  2021      1      7965056
# ..                        ...   ...    ...          ...
# 67            Women's Apparel  2021     12     14910708
# 68    Men's Athletic Footwear  2021     12     13195038
# 69              Men's Apparel  2021     12     10658726
# 70    Women's Street Footwear  2021     12     10547148
# 71  Women's Athletic Footwear  2021     12      9549962
#
# [72 rows x 4 columns]

# %%
gender07 = gender07.sort_values('Product',ascending=False)
sns.lineplot(data=gender07,x=gender07['month'],y='total_sales',hue="Product")
plt.title("Sales trend by Product (2021)")
plt.xticks(np.arange(1,13))
#plt.ylim(0,30000000)
plt.show()

# %% [markdown]
# 4. 월별로 제품종류의 판매량 변화
# -

# %% [markdown]
# ## retailer

# %% [markdown]
# ### 시장 점유율

# %%
retailer02 = pd.read_csv('/content/drive/MyDrive/project01_adidas/retailer02.csv')
retailer02
# Out:
#         retailer  market_share
# 0      West Gear     242964333
# 1    Foot Locker     220094720
# 2  Sports Direct     182470997
# 3         Kohl's     102114753
# 4         Amazon      77698912
# 5        Walmart      74558410

# %%
retailer02 = retailer02.sort_values('retailer',ascending=False)
plt.title("Market Share by Retailer")
plt.pie(retailer02['market_share'],labels = retailer02['retailer'], autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# 1. 시장점유율
# - retailer 6개
# - West Gear, Foot Locker가 1,2 위를 차지하고 있음.
# - 상위 그룹 3개와 하위 그룹 3개 간의 차이가 큼.
# - 2020,2021년 합친 그래프도 2021년 매출이 2020년보다 커서 그 영향으로 인해, 2021년 그래프와 더 유사한 모습을 하고 있는 것으로 보임.

# %% [markdown]
# ### 2021, 2022 시장점유율

# %%
retailer05 = pd.read_csv('/content/drive/MyDrive/project01_adidas/retailer05.csv')
retailer05
# Out:
#          retailer  year  market_share
# 0       West Gear  2020      90299266
# 1     Foot Locker  2020      42876805
# 2         Walmart  2020      32885000
# 3   Sports Direct  2020      15261101
# 4          Kohl's  2020        758503
# 5     Foot Locker  2021     177217915
# 6   Sports Direct  2021     167209896
# 7       West Gear  2021     152665067
# 8          Kohl's  2021     101356250
# 9          Amazon  2021      77698912
# 10        Walmart  2021      41673410

# %%
# 2020
retailer05_2020 = retailer05[retailer05['year']==2020]
retailer05_2020 = retailer05_2020.sort_values('retailer',ascending=False)

plt.title("Market Share 2020 by Retailer")
plt.pie(retailer05_2020['market_share'],labels = retailer05_2020['retailer'], autopct = '%0.1f%%')
plt.show()

# %%
# 2021
retailer05_2021 = retailer05[retailer05['year']==2021]
retailer05_2021 = retailer05_2021.sort_values('retailer',ascending=False)

plt.title("Market Share 2021 by Retailer")
plt.pie(retailer05_2021['market_share'],labels = retailer05_2021['retailer'], autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# 2. 2020 → 2021 시장 점유율의 변화
# - 2020년에 West Gear가 거의 50%를 차지하고 있었는데, 2021년에는 Foot Locker, Sports Direct, West Gear가 각각 20% 조금 넘게 차지하고 있음.
# - 2020 → 2021년이 되면서 더 많은 소매점이 생겼으며, 독점 점유율이 낮아졌음을 확인할 수 있다.

# %% [markdown]
# ### retailer별, 년도별, 월별 total sales

# %%
retailer03 = pd.read_csv('/content/drive/MyDrive/project01_adidas/retailer03.csv')
retailer03
# Out:
#          retailer  year  month  total_sales
# 0     Foot Locker  2020      1      9852930
# 1       West Gear  2020      1      6400816
# 2       West Gear  2020      2      9970276
# 3     Foot Locker  2020      2      5027712
# 4     Foot Locker  2020      3     10344219
# 5       West Gear  2020      3      7316358
# 6       West Gear  2020      4     15223027
# 7         Walmart  2020      4      8577117
# 8     Foot Locker  2020      4       806862
# 9       West Gear  2020      5      9259295
# 10        Walmart  2020      5      4398848
# 11  Sports Direct  2020      5      2117485
# 12    Foot Locker  2020      5      1142386
# 13      West Gear  2020      6      8829819
# 14      West Gear  2020      7     13085250
# 15  Sports Direct  2020      7      3324723
# 16        Walmart  2020      7       736040
# 17        Walmart  2020      8      8123087
# 18    Foot Locker  2020      8      6353845
# 19      West Gear  2020      8      2827055
# ...

# %%
#2020
retailer03 = retailer03.sort_values('retailer',ascending=False)
sns.lineplot(data=retailer03,x=retailer03['month'],y='total_sales',hue="retailer")
plt.title("Sales trend by retailer(2020)")
plt.xticks(np.arange(1,13))
plt.ylim(0,30000000)
plt.show()

# %%
retailer04 = pd.read_csv('/content/drive/MyDrive/project01_adidas/retailer04.csv')
retailer04
# Out:
#          retailer  year  month  total_sales
# 0       West Gear  2021      1     23993565
# 1     Foot Locker  2021      1     10706596
# 2          Kohl's  2021      1      9352035
# 3   Sports Direct  2021      1      7259584
# 4          Amazon  2021      1      3913616
# ..            ...   ...    ...          ...
# 66      West Gear  2021     12     16533083
# 67  Sports Direct  2021     12     15577391
# 68         Amazon  2021     12      9715707
# 69         Kohl's  2021     12      7364534
# 70        Walmart  2021     12      2489138
#
# [71 rows x 4 columns]

# %%
retailer04 = retailer04.sort_values('retailer',ascending=False)

# %%
#2021
sns.lineplot(data=retailer04,x=retailer04['month'],y='total_sales',hue="retailer")
plt.title("Sales trend by retailer(2021)")
plt.xticks(np.arange(1,13))
plt.ylim(0,30000000)
plt.show()

# %% [markdown]
# 3. 소매점별 년도, 월별 추이 변화
# - Amazon은 2020년에 판매가 전혀 없음. —> amazon에 adidas가 2021에 들어왔음을 짐작할 수 있음.
# - 2020년에 West Gear가 대부분의 월에서 매출이 많음을 알 수 있음.
# - 전체적으로 2020년 매출이 2021년 매출보다 적음을 알 수 있음.

# %% [markdown]
# ## GENDER

# %% [markdown]
# ### 남성/여성 total sales 비교

# %%
gender01 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender01.csv')
gender01
# Out:
#   gender  total_sales
# 0    Men    486228556
# 1  Women    413673569

# %%
plt.title("Total Sales by Gender")
sns.barplot(x="gender", y="total_sales", data=gender01)
#plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# 1. 성별에 따른 판매량
# - 남성의 판매량이 더 높음.

# %% [markdown]
# ### 월별 성별에 따른 판매량

# %%
gender02 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender02.csv')
gender02
# Out:
#    gender  year  month  total_sales
# 0     Men  2020      1      8787815
# 1   Women  2020      1      7465931
# 2     Men  2020      2      8223345
# 3   Women  2020      2      6774643
# 4     Men  2020      3      9084556
# 5   Women  2020      3      8576021
# 6     Men  2020      4     13390287
# 7   Women  2020      4     11216719
# 8     Men  2020      5      9115908
# 9   Women  2020      5      7802106
# 10  Women  2020      6      4609814
# 11    Men  2020      6      4220005
# 12    Men  2020      7      9289084
# 13  Women  2020      7      7856929
# 14    Men  2020      8     10515602
# 15  Women  2020      8      9362378
# 16  Women  2020      9      9298918
# 17    Men  2020      9      9005518
# 18  Women  2020     10      5678130
# 19    Men  2020     10      5158139
# 20    Men  2020     11      4849448
# 21  Women  2020     11      3772852
# 22    Men  2020     12      4194739
# 23  Women  2020     12      3831788

# %%
sns.lineplot(data=gender02,x=gender02['month'],y='total_sales',hue="gender")
plt.title("Sales trend by Gender(2020)")
plt.xticks(np.arange(1,13))
#plt.ylim(0,30000000)
plt.show()

# %%
gender03 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender03.csv')
gender03
# Out:
#    gender  year  month  total_sales
# 0     Men  2021      1     30151434
# 1   Women  2021      1     25073962
# 2     Men  2021      2     26102690
# 3   Women  2021      2     19999475
# 4     Men  2021      3     21684285
# 5   Women  2021      3     17464247
# 6     Men  2021      4     25259436
# 7   Women  2021      4     22473528
# 8     Men  2021      5     33857015
# 9   Women  2021      5     29732666
# 10    Men  2021      6     33759387
# 11  Women  2021      6     32158166
# 12    Men  2021      7     42978995
# 13  Women  2021      7     35355686
# 14    Men  2021      8     41290348
# 15  Women  2021      8     30997873
# 16    Men  2021      9     33355510
# 17  Women  2021      9     26001513
# 18    Men  2021     10     28730073
# 19  Women  2021     10     24344691
# 20    Men  2021     11     30417325
# 21  Women  2021     11     28817715
# 22    Men  2021     12     42807612
# 23  Women  2021     12     35007818

# %%
sns.lineplot(data=gender03,x=gender03['month'],y='total_sales',hue="gender")
plt.title("Sales trend by Gender(2021)")
plt.xticks(np.arange(1,13))
#plt.ylim(0,30000000)
plt.show()

# %% [markdown]
# 2. 년도별, 월별 남성/여성 total sales의 차이
# - 2021년은 모든 달에서 남성제품의 판매량이 높음.
# - 2020년에는 6월,9월에 여성제품의 판매량이 높으며, 나머지 달은 남성제품 판매량이 높음.

# %% [markdown]
# ### 성별에 따른 상품종류의 판매량

# %%
gender04 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender04.csv')
gender04
# Out:
#                    Product  total_sales
# 0    Men's Street Footwear    208826244
# 1  Men's Athletic Footwear    153673680
# 2            Men's Apparel    123728632

# %%
plt.title("Total Sales by Men Prouduct")
sns.barplot(x="Product", y="total_sales", data=gender04)
#plt.xticks(rotation="vertical")
plt.show()

# %%
gender05 = pd.read_csv('/content/drive/MyDrive/project01_adidas/gender05.csv')
gender05
# Out:
#                      Product  total_sales
# 0            Women's Apparel    179038860
# 1    Women's Street Footwear    128002813
# 2  Women's Athletic Footwear    106631896

# %%
plt.title("Total Sales by Women Prouduct")
sns.barplot(x="Product", y="total_sales", data=gender05)
#plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# 3. 성별에 따라 어떤 상품군이 판매량이 높은지
# - 남성제품은 신발 판매량이 높고, 여성제품은 옷 판매량이 더 높음.
